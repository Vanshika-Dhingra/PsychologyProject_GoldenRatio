# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
df = pd.read_csv('Experiment2Data_1xShapes2_merged.csv')

# Select only the columns with shape names
shape_columns = ['circle.png', 'ellipse_angle_0.png', 'ellipse_angle_90.png',
                  'parallelogram_angle_0.png', 'parallelogram_angle_90.png',
                  'rectangle_angle_0.png', 'rectangle_angle_90.png',
                  'square.png', 'trapezium_angle_0.png', 'trapezium_angle_90.png']

# Set the number of rows and columns for the subplot grid
num_rows = 3
num_cols = 4

# Create a subplot grid
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10))

# Flatten the 2D array of subplots into a 1D array
axes = axes.flatten()

# Iterate through shape columns and create binned bar charts in subplots
for i, shape_column in enumerate(shape_columns):
    # Plotting a histogram for the current shape column
    df[df[shape_column] > 5.] = 5

    axes[i].axvline(x=1.618,c='r')
    axes[i].hist(df[shape_column], bins=40, edgecolor='black')
    
    # Setting plot labels and title
    axes[i].set_xlabel('Values')
    axes[i].set_ylabel('Frequency')
    axes[i].set_title(f'Bar Chart for {shape_column}')

# Adjust layout for better spacing
plt.tight_layout()

# Display the plots
plt.show()

# %%
df = pd.read_csv('Experiment2Data_1xShapes2_merged.csv')
df
# Out:
#            Name  circle.png  ellipse_angle_0.png  ellipse_angle_90.png  \
# 0         Ashna    1.050138             1.063559              1.023804
# 1       Bhargav    7.840703             1.098647              7.681365
# 2   KhushiGoyal    1.124770             1.055306              1.023694
# 3        Pavani    1.106142             1.148444              1.130984
# 4      Pranjali    1.168404             1.132600              1.152474
# 5        Prisha    1.082516             1.002399              1.058909
# 6        Shreyu    8.632481             1.057673              1.336830
# 7         Ashna    1.096846             1.152879              1.002057
# 8       Bhargav    7.572292             1.024362              1.115165
# 9   KhushiGoyal    1.138189             1.015610              1.237071
# 10       Pavani    1.041170             1.014643              1.010370
# 11     Pranjali    1.082983             1.041335              1.077734
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
df = pd.read_csv('Experiment2Data_3xShapes2_merged.csv')

# Select only the columns with shape names
shape_columns = ['circle_3x.png', 'ellipse_angle_0_3x.png', 'ellipse_angle_90_3x.png',
                  'parallelogram_angle_0_3x.png', 'parallelogram_angle_90_3x.png',
                  'rectangle_angle_0_3x.png', 'rectangle_angle_90_3x.png',
                  'square_3x.png', 'trapezium_angle_0_3x.png', 'trapezium_angle_90_3x.png']

# Set the number of rows and columns for the subplot grid
num_rows = 3
num_cols = 4

# Create a subplot grid
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10))

# Flatten the 2D array of subplots into a 1D array
axes = axes.flatten()

# Iterate through shape columns and create binned bar charts in subplots
for i, shape_column in enumerate(shape_columns):
    # Plotting a histogram for the current shape column
    df[df[shape_column] > 7.] = 7
    axes[i].axvline(x=1.618,c='r')   
    axes[i].hist(df[shape_column], bins=20, edgecolor='black')
    
    # Setting plot labels and title
    axes[i].set_xlabel('Values')
    axes[i].set_ylabel('Frequency')
    axes[i].set_title(f'Bar Chart for {shape_column}')

# Adjust layout for better spacing
plt.tight_layout()

# Display the plots
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read the CSV file into a DataFrame
df = pd.read_csv('merged_file.csv')

# Select only the columns with shape names
shape_columns = ['circle.png', 'ellipse_angle_0.png', 'ellipse_angle_90.png',
                  'parallelogram_angle_0.png', 'parallelogram_angle_90.png',
                  'rectangle_angle_0.png', 'rectangle_angle_90.png',
                  'square.png', 'trapezium_angle_0.png', 'trapezium_angle_90.png']

# Set the number of rows and columns for the subplot grid
num_rows = 3
num_cols = 4

# Create a subplot grid
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10))

# Flatten the 2D array of subplots into a 1D array
axes = axes.flatten()

# Iterate through shape columns and create binned bar charts in subplots
for i, shape_column in enumerate(shape_columns):
    # Plotting a histogram for the current shape column
    df[df[shape_column] > 7.] = 7

    axes[i].axvline(x=1.618,c='r')
    axes[i].hist(df[shape_column], bins=30, edgecolor='black')
    
    # Setting plot labels and title
    axes[i].set_xlabel('Values')
    axes[i].set_ylabel('Frequency')
    axes[i].set_title(f'Bar Chart for {shape_column}')

# Adjust layout for better spacing
plt.tight_layout()

# Display the plots
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# Read data from CSV file
df = pd.read_csv('mergedFile_half.csv')

# Extract the basis for decisions column
basis_column = 'What was the basis for your divisions?'

# Concatenate all sentences
all_text = ' '.join(df[basis_column].dropna())

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(all_text)

# Display the WordCloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import pandas as pd

# Read data from CSV file
df = pd.read_csv('merged_file.csv')

# Extract columns
gender_column = 'Gender'
shape_columns = ['circle.png', 'ellipse_angle_0.png', 'ellipse_angle_90.png',
                  'parallelogram_angle_0.png', 'parallelogram_angle_90.png',
                  'rectangle_angle_0.png', 'rectangle_angle_90.png',
                  'square.png', 'trapezium_angle_0.png', 'trapezium_angle_90.png']

# Group data by gender and compute summary statistics
gender_stats = df.groupby(gender_column)[shape_columns].describe()

# Print summary statistics in markdown table format
print(gender_stats.to_markdown())
# Out:
# | Gender   |   ('circle.png', 'count') |   ('circle.png', 'mean') |   ('circle.png', 'std') |   ('circle.png', 'min') |   ('circle.png', '25%') |   ('circle.png', '50%') |   ('circle.png', '75%') |   ('circle.png', 'max') |   ('ellipse_angle_0.png', 'count') |   ('ellipse_angle_0.png', 'mean') |   ('ellipse_angle_0.png', 'std') |   ('ellipse_angle_0.png', 'min') |   ('ellipse_angle_0.png', '25%') |   ('ellipse_angle_0.png', '50%') |   ('ellipse_angle_0.png', '75%') |   ('ellipse_angle_0.png', 'max') |   ('ellipse_angle_90.png', 'count') |   ('ellipse_angle_90.png', 'mean') |   ('ellipse_angle_90.png', 'std') |   ('ellipse_angle_90.png', 'min') |   ('ellipse_angle_90.png', '25%') |   ('ellipse_angle_90.png', '50%') |   ('ellipse_angle_90.png', '75%') |   ('ellipse_angle_90.png', 'max') |   ('parallelogram_angle_0.png', 'count') |   ('parallelogram_angle_0.png', 'mean') |   ('parallelogram_angle_0.png', 'std') |   ('parallelogram_angle_0.png', 'min') |   ('parallelogram_angle_0.png', '
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read data from CSV file
df = pd.read_csv('merged_file.csv')

# Extract columns
gender_column = 'Gender'
shape_columns = ['circle.png', 'ellipse_angle_0.png', 'ellipse_angle_90.png',
                  'parallelogram_angle_0.png', 'parallelogram_angle_90.png',
                  'rectangle_angle_0.png', 'rectangle_angle_90.png',
                  'square.png', 'trapezium_angle_0.png', 'trapezium_angle_90.png']

# Calculate means for each shape column by gender
means_by_gender = df.groupby(gender_column)[shape_columns].median()

# Plot a bar chart for each shape column comparing means by gender
means_by_gender.T.plot(kind='bar', color=['blue', 'pink'])
plt.axhline(y=1.618,c='r')
plt.title('Comparison of Means by Gender')
plt.xlabel('Shape Column')
plt.ylabel('Mean Ratio')
plt.show()

# %%
import pandas as pd

# Read data from CSV file
df = pd.read_csv('merged_file.csv')

# Extract columns
artistic_training_column = 'Rate yourself on the basis of artistic training'
shape_columns = ['circle.png', 'ellipse_angle_0.png', 'ellipse_angle_90.png',
                  'parallelogram_angle_0.png', 'parallelogram_angle_90.png',
                  'rectangle_angle_0.png', 'rectangle_angle_90.png',
                  'square.png', 'trapezium_angle_0.png', 'trapezium_angle_90.png']

# Group data by artistic training and compute summary statistics
artistic_training_stats = df.groupby(artistic_training_column)[shape_columns].describe()

# Print summary statistics in markdown table format
print(artistic_training_stats.to_markdown())
# Out:
# |   Rate yourself on the basis of artistic training |   ('circle.png', 'count') |   ('circle.png', 'mean') |   ('circle.png', 'std') |   ('circle.png', 'min') |   ('circle.png', '25%') |   ('circle.png', '50%') |   ('circle.png', '75%') |   ('circle.png', 'max') |   ('ellipse_angle_0.png', 'count') |   ('ellipse_angle_0.png', 'mean') |   ('ellipse_angle_0.png', 'std') |   ('ellipse_angle_0.png', 'min') |   ('ellipse_angle_0.png', '25%') |   ('ellipse_angle_0.png', '50%') |   ('ellipse_angle_0.png', '75%') |   ('ellipse_angle_0.png', 'max') |   ('ellipse_angle_90.png', 'count') |   ('ellipse_angle_90.png', 'mean') |   ('ellipse_angle_90.png', 'std') |   ('ellipse_angle_90.png', 'min') |   ('ellipse_angle_90.png', '25%') |   ('ellipse_angle_90.png', '50%') |   ('ellipse_angle_90.png', '75%') |   ('ellipse_angle_90.png', 'max') |   ('parallelogram_angle_0.png', 'count') |   ('parallelogram_angle_0.png', 'mean') |   ('parallelogram_angle_0.png', 'std') |   ('parallelogram_angle_0.png', '
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read data from CSV file
df = pd.read_csv('merged_file.csv')

# Extract columns
artistic_training_column = 'Rate yourself on the basis of artistic training'
shape_columns = ['circle.png', 'ellipse_angle_0.png', 'ellipse_angle_90.png',
                  'parallelogram_angle_0.png', 'parallelogram_angle_90.png',
                  'rectangle_angle_0.png', 'rectangle_angle_90.png',
                  'square.png', 'trapezium_angle_0.png', 'trapezium_angle_90.png']

# Create two groups based on artistic training
df['Artistic Training Group'] = pd.cut(df[artistic_training_column], bins=[0, 3, 5], labels=['Low-Medium', 'High'])

# Group data by the new column and compute median for each shape column
grouped_medians = df.groupby('Artistic Training Group')[shape_columns].median()

# Compute the difference in medians
difference_in_medians = grouped_medians.loc['High'] - grouped_medians.loc['Low-Medium']

# Plot a bar chart for the differences in medians
fig, axes = plt.subplots(figsize=(12, 6))

difference_in_medians.plot(kind='bar', ax=axes, color='lightblue', width=0.8)
axes.set_title('Differences in Medians between High and Low-Medium Artistic Training')
axes.set_xlabel('Shape Column')
axes.set_ylabel('Difference in Medians')

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Read data from CSV file
df = pd.read_csv('merged_file.csv')

# Extract columns
artistic_training_column = 'Rate yourself on the basis of artistic training'
shape_columns = ['circle.png', 'ellipse_angle_0.png', 'ellipse_angle_90.png',
                  'parallelogram_angle_0.png', 'parallelogram_angle_90.png',
                  'rectangle_angle_0.png', 'rectangle_angle_90.png',
                  'square.png', 'trapezium_angle_0.png', 'trapezium_angle_90.png']

# Create two groups based on artistic training
df['Artistic Training Group'] = pd.cut(df[artistic_training_column], bins=[0, 3, 5], labels=['Low-Medium', 'High'])

# Group data by the new column and compute median for each shape column
grouped_medians = df.groupby('Artistic Training Group')[shape_columns].median()

# Plot a grouped bar chart for the medians
fig, axes = plt.subplots(figsize=(12, 6))

grouped_medians.T.plot(kind='bar', ax=axes, color=['lightblue', 'lightgreen'], width=0.8)
axes.axhline(y=1.618,c='r')
axes.set_title('Medians of Shape Columns by Artistic Training')
axes.set_xlabel('Shape Column')
axes.set_ylabel('Median Value')
axes.legend(title='Artistic Training Group')

plt.show()
