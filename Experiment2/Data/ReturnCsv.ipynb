# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import glob
from PIL import Image

# %%
path = './Person//1xShapes/*'
arr = []
for p in glob.glob(path):
#     img=cv2.imread(p,cv2.IMREAD_UNCHANGED)
    img = Image.open(p)
    print(np.asarray(img).shape)
    arr.append(np.asarray(img))
    plt.imshow(img,cmap='gray')
    plt.show()
#     break

# %%
from PIL import Image

def calculate_black_to_white_ratio(image_path):
    try:
        # Load the image
        image = Image.open(image_path)

        # Convert the image to RGBA mode to include alpha (transparency) channel
        image = image.convert("RGBA")

        # Get pixel data
        pixels = list(image.getdata())

        # Count black (0) and white (255) pixels while excluding transparent pixels
        black_pixels = 0
        white_pixels = 0

        for pixel in pixels:
            r, g, b, a = pixel
            if a > 0:  # Exclude transparent pixels
                if r == 0 and g == 0 and b == 0:
                    black_pixels += 1
                elif r == 255 and g == 255 and b == 255:
                    white_pixels += 1

        # Calculate the ratio
        if white_pixels == 0:
            ratio = 0  # To avoid division by zero
        else:
            ratio = max(black_pixels / white_pixels, white_pixels/black_pixels )

        return black_pixels, white_pixels, ratio

    except Exception as e:
        return None

# %%
final= []
path = './**/**/*'
for p in glob.glob(path):
    result = calculate_black_to_white_ratio(p)

    if result:
        black_pixels, white_pixels, ratio = result
        res = {'Path':p,'Black':black_pixels,'White':white_pixels,'Ratio':ratio}
        final.append(res)
        print(p)
        print(f"Black Pixels: {black_pixels}")
        print(f"White Pixels: {white_pixels}")
        print(f"Black to White Ratio: {ratio:.2f}")
        print()
    else:
        print("Error loading the image or calculating the ratio.")
# Out:
# ./Akshat/3xShapes/circle_3x.png
# Black Pixels: 137447
# White Pixels: 144242
# Black to White Ratio: 1.05
#
# ./Akshat/3xShapes/square_3x.png
# Black Pixels: 144804
# White Pixels: 144788
# Black to White Ratio: 1.00
#
# ./Akshat/3xShapes/ellipse_angle_90_3x.png
# Black Pixels: 203412
# White Pixels: 219347
# Black to White Ratio: 1.08
#
# ./Akshat/3xShapes/rectangle_angle_0_3x.png
# Black Pixels: 220215
# White Pixels: 214697
# Black to White Ratio: 1.03
#
# ./Akshat/3xShapes/ellipse_angle_0_3x.png
# Black Pixels: 226931
# White Pixels: 195835
# Black to White Ratio: 1.16
#
# ./Akshat/3xShapes/trapezium_angle_0_3x.png
# Black Pixels: 179735
# White Pixels: 88749
# Black to White Ratio: 2.03
#
# ./Akshat/3xShapes/parallelogram_angle_0_3x.png
# Black Pixels: 134549
# White Pixels: 133358
# Black to White Ratio: 1.01
#
# ./Akshat/3xShapes/parallelogram_angle_90_3x.png
# Black Pixels: 133953
# White Pixels: 133953
# Black to White Ratio: 1.00
#
# ./Akshat/3xShapes/trapezium_angle_90_3x.png
# Black Pixels: 182497
# White Pixels: 86044
# Black to White Ratio: 2.12
#
# ./Akshat/3xShapes/rectangle_angle_90_3x.png
# Black Pixels: 218041
# White Pixels: 216841
# Black to White Ratio: 1.01
#
# ./Akshat/3xShapes2/circle_3x.png
# Black Pixels: 138101
# White Pixels: 144049
# Black to White Ratio: 1.04
#
# ./Akshat/3xShapes2/square_3x.png
# Black Pixels: 149098
# White Pixels: 141517
# Black to White Ratio: 1.05
#
# ./Akshat/3xShapes2/ellipse_angle_90_3x.png
# Black Pixels: 214350
# White Pixels: 209354
# Black to White Ratio: 1.02
#
# ./Akshat/3xShapes2/rectangle_angle_0_3x.png
# Black Pixels: 241458
# White Pixels: 194488
# Black to White Ratio: 1.24
#
# ./Akshat/3xShapes2/ellipse_angle_0_3x.png
# Black Pixels: 214604
# White Pixels: 208486
# Black to White Ratio: 1.03
#
# ./Akshat/3xShapes2/trapezium_angle_0_3x.png
# Black Pixels: 165813
# White Pixels: 103640
# Black to White Ratio: 1.60
#
# ./Akshat/3xShapes2/parallelogram_angle_0_3x.png
# Black Pixels: 145338
# White Pixels: 124176
# Black to White Ratio: 1.17
#
# ./Akshat/3xShapes2/parallelogram_angle_90_3x.png
# Black Pixels: 145230
# White Pixels: 123695
# Black to White Ratio: 1.17
#
# ./Akshat/3xShapes2/trapezium_angle_90_3x.png
# Black Pixels: 133071
# White Pixels: 136257
# Black to White Ratio: 1.02
#
# ./Akshat/3xShapes2/rectangle_angle_90_3x.png
# Black Pixels: 234360
# White Pixels: 203118
# Black to White Ratio: 1.15
#
# ./Umang/3xShapes/circle_3x.png
# Black Pixels: 134224
# White Pixels: 147711
# Black to White Ratio: 1.10
#
# ./Umang/3xShapes/square_3x.png
# Black Pixels: 139746
# White Pixels: 150589
# Black to White Ratio: 1.08
#
# ./Umang/3xShapes/ellipse_angle_90_3x.png
# Black Pixels: 207200
# White Pixels: 215660
# Black to White Ratio: 1.04
#
# ./Umang/3xShapes/rectangle_angle_0_3x.png
# Black Pixels: 229880
# White Pixels: 206477
# Black to White Ratio: 1.11
#
# ./Umang/3xShapes/ellipse_angle_0_3x.png
# Black Pixels: 44881
# White Pixels: 379046
# Black to White Ratio: 8.45
#
# ./Umang/3xShapes/trapezium_angle_0_3x.png
# Black Pixels: 231310
# White Pixels: 37879
# Black to White Ratio: 6.11
#
# ./Umang/3xShapes/parallelogram_angle_0_3x.png
# Black Pixels: 129160
# White Pixels: 139900
# Black to White Ratio: 1.08
#
# ./Umang/3xShapes/parallelogram_angle_90_3x.png
# Black Pixels: 124094
# White Pixels: 145410
# Black to White Ratio: 1.17
#
# ./Umang/3xShapes/trapezium_angle_90_3x.png
# Black Pixels: 157648
# White Pixels: 111772
# Black to White Ratio: 1.41
#
# ./Umang/3xShapes/rectangle_angle_90_3x.png
# Black Pixels: 240786
# White Pixels: 194946
# Black to White Ratio: 1.24
#
# ./Umang/3xShapes2/circle_3x.png
# Black Pixels: 42259
# White Pixels: 239993
# Black to White Ratio: 5.68
#
# ./Umang/3xShapes2/square_3x.png
# Black Pixels: 124200
# White Pixels: 166376
# Black to White Ratio: 1.34
#
# ./Umang/3xShapes2/ellipse_angle_90_3x.png
# Black Pixels: 131512
# White Pixels: 292131
# Black to White Ratio: 2.22
#
# ./Umang/3xShapes2/rectangle_angle_0_3x.png
# Black Pixels: 221466
# White Pixels: 214342
# Black to White Ratio: 1.03
#
# ./Umang/3xShapes2/ellipse_angle_0_3x.png
# Black Pixels: 352343
# White Pixels: 71077
# Black to White Ratio: 4.96
#
# ./Umang/3xShapes2/trapezium_angle_0_3x.png
# Black Pixels: 146427
# White Pixels: 123217
# Black to White Ratio: 1.19
#
# ./Umang/3xShapes2/parallelogram_angle_0_3x.png
# Black Pixels: 112403
# White Pixels: 157106
# Black to White Ratio: 1.40
#
# ./Umang/3xShapes2/parallelogram_angle_90_3x.png
# Black Pixels: 141470
# White Pixels: 127702
# Black to White Ratio: 1.11
#
# ./Umang/3xShapes2/trapezium_angle_90_3x.png
# Black Pixels: 128409
# White Pixels: 140883
# Black to White Ratio: 1.10
#
# ./Umang/3xShapes2/rectangle_angle_90_3x.png
# Black Pixels: 196271
# White Pixels: 240134
# Black to White Ratio: 1.22
#
# ./Harshit/3xShapes/circle_3x.png
# Black Pixels: 139812
# White Pixels: 141253
# Black to White Ratio: 1.01
#
# ./Harshit/3xShapes/square_3x.png
# Black Pixels: 144215
# White Pixels: 145928
# Black to White Ratio: 1.01
#
# ./Harshit/3xShapes/ellipse_angle_90_3x.png
# Black Pixels: 237195
# White Pixels: 184742
# Black to White Ratio: 1.28
#
# ./Harshit/3xShapes/rectangle_angle_0_3x.png
# Black Pixels: 397063
# White Pixels: 38266
# Black to White Ratio: 10.38
#
# ./Harshit/3xShapes/ellipse_angle_0_3x.png
# Black Pixels: 245234
# White Pixels: 177817
# Black to White Ratio: 1.38
#
# ./Harshit/3xShapes/trapezium_angle_0_3x.png
# Black Pixels: 268159
# White Pixels: 2120
# Black to White Ratio: 126.49
#
# ./Harshit/3xShapes/parallelogram_angle_0_3x.png
# Black Pixels: 131764
# White Pixels: 136476
# Black to White Ratio: 1.04
#
# ./Harshit/3xShapes/parallelogram_angle_90_3x.png
# Black Pixels: 143325
# White Pixels: 126176
# Black to White Ratio: 1.14
#
# ./Harshit/3xShapes/trapezium_angle_90_3x.png
# Black Pixels: 92404
# White Pixels: 176629
# Black to White Ratio: 1.91
#
# ./Harshit/3xShapes/rectangle_angle_90_3x.png
# Black Pixels: 221940
# White Pixels: 213923
# Black to White Ratio: 1.04
#
# ./Harshit/3xShapes2/circle_3x.png
# Black Pixels: 157142
# White Pixels: 124053
# Black to White Ratio: 1.27
#
# ./Harshit/3xShapes2/square_3x.png
# Black Pixels: 45
# White Pixels: 291539
# Black to White Ratio: 6478.64
#
# ./Harshit/3xShapes2/ellipse_angle_90_3x.png
# Black Pixels: 7568
# White Pixels: 416969
# Black to White Ratio: 55.10
#
# ./Harshit/3xShapes2/rectangle_angle_0_3x.png
# Black Pixels: 360265
# White Pixels: 75288
# Black to White Ratio: 4.79
#
# ./Harshit/3xShapes2/ellipse_angle_0_3x.png
# Black Pixels: 211313
# White Pixels: 211562
# Black to White Ratio: 1.00
#
# ./Harshit/3xShapes2/trapezium_angle_0_3x.png
# Black Pixels: 270305
# White Pixels: 92
# Black to White Ratio: 2938.10
#
# ./Harshit/3xShapes2/parallelogram_angle_0_3x.png
# Black Pixels: 6008
# White Pixels: 263597
# Black to White Ratio: 43.87
#
# ./Harshit/3xShapes2/parallelogram_angle_90_3x.png
# Black Pixels: 155841
# White Pixels: 112944
# Black to White Ratio: 1.38
#
# ./Harshit/3xShapes2/trapezium_angle_90_3x.png
# Black Pixels: 264906
# White Pixels: 4140
# Black to White Ratio: 63.99
#
# ./Harshit/3xShapes2/rectangle_angle_90_3x.png
# Black Pixels: 212504
# White Pixels: 223932
# Black to White Ratio: 1.05
#
# ./Shreyu/1xShapes/trapezium_angle_90.png
# Black Pixels: 9959
# White Pixels: 19541
# Black to White Ratio: 1.96
#
# ./Shreyu/1xShapes/parallelogram_angle_90.png
# Black Pixels: 14212
# White Pixels: 14886
# Black to White Ratio: 1.05
#
# ./Shreyu/1xShapes/ellipse_angle_90.png
# Black Pixels: 24240
# White Pixels: 21285
# Black to White Ratio: 1.14
#
# ./Shreyu/1xShapes/circle.png
# Black Pixels: 16608
# White Pixels: 14559
# Black to White Ratio: 1.14
#
# ./Shreyu/1xShapes/rectangle_angle_0.png
# Black Pixels: 25400
# White Pixels: 22040
# Black to White Ratio: 1.15
#
# ./Shreyu/1xShapes/rectangle_angle_90.png
# Black Pixels: 25285
# White Pixels: 22047
# Black to White Ratio: 1.15
#
# ./Shreyu/1xShapes/trapezium_angle_0.png
# Black Pixels: 21287
# White Pixels: 7223
# Black to White Ratio: 2.95
#
# ./Shreyu/1xShapes/ellipse_angle_0.png
# Black Pixels: 23784
# White Pixels: 23065
# Black to White Ratio: 1.03
#
# ./Shreyu/1xShapes/parallelogram_angle_0.png
# Black Pixels: 8675
# White Pixels: 20947
# Black to White Ratio: 2.41
#
# ./Shreyu/1xShapes/square.png
# Black Pixels: 16622
# White Pixels: 14963
# Black to White Ratio: 1.11
#
# ./Shreyu/1xShapes2/trapezium_angle_90.png
# Black Pixels: 13024
# White Pixels: 16627
# Black to White Ratio: 1.28
#
# ./Shreyu/1xShapes2/parallelogram_angle_90.png
# Black Pixels: 12895
# White Pixels: 16653
# Black to White Ratio: 1.29
#
# ./Shreyu/1xShapes2/ellipse_angle_90.png
# Black Pixels: 26635
# White Pixels: 19924
# Black to White Ratio: 1.34
#
# ./Shreyu/1xShapes2/circle.png
# Black Pixels: 27693
# White Pixels: 3208
# Black to White Ratio: 8.63
#
# ./Shreyu/1xShapes2/rectangle_angle_0.png
# Black Pixels: 35798
# White Pixels: 11936
# Black to White Ratio: 3.00
#
# ./Shreyu/1xShapes2/rectangle_angle_90.png
# Black Pixels: 14730
# White Pixels: 33203
# Black to White Ratio: 2.25
#
# ./Shreyu/1xShapes2/trapezium_angle_0.png
# Black Pixels: 19686
# White Pixels: 10024
# Black to White Ratio: 1.96
#
# ./Shreyu/1xShapes2/ellipse_angle_0.png
# Black Pixels: 23584
# White Pixels: 22298
# Black to White Ratio: 1.06
#
# ./Shreyu/1xShapes2/parallelogram_angle_0.png
# Black Pixels: 20933
# White Pixels: 8443
# Black to White Ratio: 2.48
#
# ./Shreyu/1xShapes2/square.png
# Black Pixels: 11690
# White Pixels: 19859
# Black to White Ratio: 1.70
#
# ./Keshav/3xShapes/circle_3x.png
# Black Pixels: 146053
# White Pixels: 135607
# Black to White Ratio: 1.08
#
# ./Keshav/3xShapes/square_3x.png
# Black Pixels: 147163
# White Pixels: 143368
# Black to White Ratio: 1.03
#
# ./Keshav/3xShapes/ellipse_angle_90_3x.png
# Black Pixels: 394912
# White Pixels: 27129
# Black to White Ratio: 14.56
#
# ./Keshav/3xShapes/rectangle_angle_0_3x.png
# Black Pixels: 206277
# White Pixels: 230080
# Black to White Ratio: 1.12
#
# ./Keshav/3xShapes/ellipse_angle_0_3x.png
# Black Pixels: 201046
# White Pixels: 220956
# Black to White Ratio: 1.10
#
# ./Keshav/3xShapes/trapezium_angle_0_3x.png
# Black Pixels: 167211
# White Pixels: 101906
# Black to White Ratio: 1.64
#
# ./Keshav/3xShapes/parallelogram_angle_0_3x.png
# Black Pixels: 135324
# White Pixels: 133202
# Black to White Ratio: 1.02
#
# ./Keshav/3xShapes/parallelogram_angle_90_3x.png
# Black Pixels: 146831
# White Pixels: 120109
# Black to White Ratio: 1.22
#
# ./Keshav/3xShapes/trapezium_angle_90_3x.png
# Black Pixels: 175650
# White Pixels: 92871
# Black to White Ratio: 1.89
#
# ./Keshav/3xShapes/rectangle_angle_90_3x.png
# Black Pixels: 68044
# White Pixels: 366942
# Black to White Ratio: 5.39
#
# ./Keshav/3xShapes2/circle_3x.png
# Black Pixels: 156235
# White Pixels: 124576
# Black to White Ratio: 1.25
#
# ./Keshav/3xShapes2/square_3x.png
# Black Pixels: 46219
# White Pixels: 243918
# Black to White Ratio: 5.28
#
# ./Keshav/3xShapes2/ellipse_angle_90_3x.png
# Black Pixels: 209810
# White Pixels: 212018
# Black to White Ratio: 1.01
#
# ./Keshav/3xShapes2/rectangle_angle_0_3x.png
# Black Pixels: 94065
# White Pixels: 340992
# Black to White Ratio: 3.63
#
# ./Keshav/3xShapes2/ellipse_angle_0_3x.png
# Black Pixels: 186406
# White Pixels: 233907
# Black to White Ratio: 1.25
#
# ./Keshav/3xShapes2/trapezium_angle_0_3x.png
# Black Pixels: 59879
# White Pixels: 209062
# Black to White Ratio: 3.49
#
# ./Keshav/3xShapes2/parallelogram_angle_0_3x.png
# Black Pixels: 147352
# White Pixels: 122112
# Black to White Ratio: 1.21
#
# ./Keshav/3xShapes2/parallelogram_angle_90_3x.png
# Black Pixels: 151040
# White Pixels: 117684
# Black to White Ratio: 1.28
#
# ./Keshav/3xShapes2/trapezium_angle_90_3x.png
# Black Pixels: 140442
# White Pixels: 128792
# Black to White Ratio: 1.09
#
# ./Keshav/3xShapes2/rectangle_angle_90_3x.png
# Black Pixels: 256611
# White Pixels: 178733
# Black to White Ratio: 1.44
#
# ./KhushiGoyal/1xShapes/trapezium_angle_90.png
# Black Pixels: 17575
# White Pixels: 12624
# Black to White Ratio: 1.39
#
# ./KhushiGoyal/1xShapes/parallelogram_angle_90.png
# Black Pixels: 14582
# White Pixels: 14767
# Black to White Ratio: 1.01
#
# ./KhushiGoyal/1xShapes/ellipse_angle_90.png
# Black Pixels: 25835
# White Pixels: 20884
# Black to White Ratio: 1.24
#
# ./KhushiGoyal/1xShapes/circle.png
# Black Pixels: 16613
# White Pixels: 14596
# Black to White Ratio: 1.14
#
# ./KhushiGoyal/1xShapes/rectangle_angle_0.png
# Black Pixels: 24174
# White Pixels: 23685
# Black to White Ratio: 1.02
#
# ./KhushiGoyal/1xShapes/rectangle_angle_90.png
# Black Pixels: 23990
# White Pixels: 23894
# Black to White Ratio: 1.00
#
# ./KhushiGoyal/1xShapes/trapezium_angle_0.png
# Black Pixels: 16077
# White Pixels: 13747
# Black to White Ratio: 1.17
#
# ./KhushiGoyal/1xShapes/ellipse_angle_0.png
# Black Pixels: 23190
# White Pixels: 23552
# Black to White Ratio: 1.02
#
# ./KhushiGoyal/1xShapes/parallelogram_angle_0.png
# Black Pixels: 14777
# White Pixels: 14576
# Black to White Ratio: 1.01
#
# ./KhushiGoyal/1xShapes/square.png
# Black Pixels: 15960
# White Pixels: 15871
# Black to White Ratio: 1.01
#
# ./KhushiGoyal/1xShapes2/trapezium_angle_90.png
# Black Pixels: 15407
# White Pixels: 14372
# Black to White Ratio: 1.07
#
# ./KhushiGoyal/1xShapes2/parallelogram_angle_90.png
# Black Pixels: 14851
# White Pixels: 14864
# Black to White Ratio: 1.00
#
# ./KhushiGoyal/1xShapes2/ellipse_angle_90.png
# Black Pixels: 23935
# White Pixels: 23381
# Black to White Ratio: 1.02
#
# ./KhushiGoyal/1xShapes2/circle.png
# Black Pixels: 16515
# White Pixels: 14683
# Black to White Ratio: 1.12
#
# ./KhushiGoyal/1xShapes2/rectangle_angle_0.png
# Black Pixels: 23760
# White Pixels: 24368
# Black to White Ratio: 1.03
#
# ./KhushiGoyal/1xShapes2/rectangle_angle_90.png
# Black Pixels: 24480
# White Pixels: 23807
# Black to White Ratio: 1.03
#
# ./KhushiGoyal/1xShapes2/trapezium_angle_0.png
# Black Pixels: 18317
# White Pixels: 11885
# Black to White Ratio: 1.54
#
# ./KhushiGoyal/1xShapes2/ellipse_angle_0.png
# Black Pixels: 22746
# White Pixels: 24004
# Black to White Ratio: 1.06
#
# ./KhushiGoyal/1xShapes2/parallelogram_angle_0.png
# Black Pixels: 16045
# White Pixels: 13890
# Black to White Ratio: 1.16
#
# ./KhushiGoyal/1xShapes2/square.png
# Black Pixels: 17460
# White Pixels: 14627
# Black to White Ratio: 1.19
#
# ./Pranjali/1xShapes/trapezium_angle_90.png
# Black Pixels: 13463
# White Pixels: 16495
# Black to White Ratio: 1.23
#
# ./Pranjali/1xShapes/parallelogram_angle_90.png
# Black Pixels: 14487
# White Pixels: 14865
# Black to White Ratio: 1.03
#
# ./Pranjali/1xShapes/ellipse_angle_90.png
# Black Pixels: 24235
# White Pixels: 22487
# Black to White Ratio: 1.08
#
# ./Pranjali/1xShapes/circle.png
# Black Pixels: 16209
# White Pixels: 14967
# Black to White Ratio: 1.08
#
# ./Pranjali/1xShapes/rectangle_angle_0.png
# Black Pixels: 24660
# White Pixels: 23980
# Black to White Ratio: 1.03
#
# ./Pranjali/1xShapes/rectangle_angle_90.png
# Black Pixels: 25245
# White Pixels: 22904
# Black to White Ratio: 1.10
#
# ./Pranjali/1xShapes/trapezium_angle_0.png
# Black Pixels: 15001
# White Pixels: 14755
# Black to White Ratio: 1.02
#
# ./Pranjali/1xShapes/ellipse_angle_0.png
# Black Pixels: 23933
# White Pixels: 22983
# Black to White Ratio: 1.04
#
# ./Pranjali/1xShapes/parallelogram_angle_0.png
# Black Pixels: 15273
# White Pixels: 14097
# Black to White Ratio: 1.08
#
# ./Pranjali/1xShapes/square.png
# Black Pixels: 15784
# White Pixels: 16046
# Black to White Ratio: 1.02
#
# ./Pranjali/1xShapes2/trapezium_angle_90.png
# Black Pixels: 15407
# White Pixels: 14366
# Black to White Ratio: 1.07
#
# ./Pranjali/1xShapes2/parallelogram_angle_90.png
# Black Pixels: 15314
# White Pixels: 14329
# Black to White Ratio: 1.07
#
# ./Pranjali/1xShapes2/ellipse_angle_90.png
# Black Pixels: 25132
# White Pixels: 21807
# Black to White Ratio: 1.15
#
# ./Pranjali/1xShapes2/circle.png
# Black Pixels: 16811
# White Pixels: 14388
# Black to White Ratio: 1.17
#
# ./Pranjali/1xShapes2/rectangle_angle_0.png
# Black Pixels: 24979
# White Pixels: 23177
# Black to White Ratio: 1.08
#
# ./Pranjali/1xShapes2/rectangle_angle_90.png
# Black Pixels: 25020
# White Pixels: 23267
# Black to White Ratio: 1.08
#
# ./Pranjali/1xShapes2/trapezium_angle_0.png
# Black Pixels: 17422
# White Pixels: 12825
# Black to White Ratio: 1.36
#
# ./Pranjali/1xShapes2/ellipse_angle_0.png
# Black Pixels: 25129
# White Pixels: 22187
# Black to White Ratio: 1.13
#
# ./Pranjali/1xShapes2/parallelogram_angle_0.png
# Black Pixels: 16120
# White Pixels: 13833
# Black to White Ratio: 1.17
#
# ./Pranjali/1xShapes2/square.png
# Black Pixels: 16380
# White Pixels: 15707
# Black to White Ratio: 1.04
#
# ./Shivam/3xShapes/circle_3x.png
# Black Pixels: 140169
# White Pixels: 141894
# Black to White Ratio: 1.01
#
# ./Shivam/3xShapes/square_3x.png
# Black Pixels: 125548
# White Pixels: 165011
# Black to White Ratio: 1.31
#
# ./Shivam/3xShapes/ellipse_angle_90_3x.png
# Black Pixels: 217983
# White Pixels: 204935
# Black to White Ratio: 1.06
#
# ./Shivam/3xShapes/rectangle_angle_0_3x.png
# Black Pixels: 24601
# White Pixels: 411804
# Black to White Ratio: 16.74
#
# ./Shivam/3xShapes/ellipse_angle_0_3x.png
# Black Pixels: 210810
# White Pixels: 212754
# Black to White Ratio: 1.01
#
# ./Shivam/3xShapes/trapezium_angle_0_3x.png
# Black Pixels: 52544
# White Pixels: 216442
# Black to White Ratio: 4.12
#
# ./Shivam/3xShapes/parallelogram_angle_0_3x.png
# Black Pixels: 201752
# White Pixels: 67149
# Black to White Ratio: 3.00
#
# ./Shivam/3xShapes/parallelogram_angle_90_3x.png
# Black Pixels: 135072
# White Pixels: 134659
# Black to White Ratio: 1.00
#
# ./Shivam/3xShapes/trapezium_angle_90_3x.png
# Black Pixels: 171643
# White Pixels: 98193
# Black to White Ratio: 1.75
#
# ./Shivam/3xShapes/rectangle_angle_90_3x.png
# Black Pixels: 214533
# White Pixels: 221448
# Black to White Ratio: 1.03
#
# ./Shivam/3xShapes2/circle_3x.png
# Black Pixels: 160534
# White Pixels: 121623
# Black to White Ratio: 1.32
#
# ./Shivam/3xShapes2/square_3x.png
# Black Pixels: 149321
# White Pixels: 140814
# Black to White Ratio: 1.06
#
# ./Shivam/3xShapes2/ellipse_angle_90_3x.png
# Black Pixels: 227311
# White Pixels: 196324
# Black to White Ratio: 1.16
#
# ./Shivam/3xShapes2/rectangle_angle_0_3x.png
# Black Pixels: 373371
# White Pixels: 62587
# Black to White Ratio: 5.97
#
# ./Shivam/3xShapes2/ellipse_angle_0_3x.png
# Black Pixels: 154901
# White Pixels: 268090
# Black to White Ratio: 1.73
#
# ./Shivam/3xShapes2/trapezium_angle_0_3x.png
# Black Pixels: 181062
# White Pixels: 88944
# Black to White Ratio: 2.04
#
# ./Shivam/3xShapes2/parallelogram_angle_0_3x.png
# Black Pixels: 132641
# White Pixels: 136957
# Black to White Ratio: 1.03
#
# ./Shivam/3xShapes2/parallelogram_angle_90_3x.png
# Black Pixels: 216911
# White Pixels: 51994
# Black to White Ratio: 4.17
#
# ./Shivam/3xShapes2/trapezium_angle_90_3x.png
# Black Pixels: 179317
# White Pixels: 89751
# Black to White Ratio: 2.00
#
# ./Shivam/3xShapes2/rectangle_angle_90_3x.png
# Black Pixels: 224808
# White Pixels: 211693
# Black to White Ratio: 1.06
#
# ./Anushka/3xShapes/circle_3x.png
# Black Pixels: 142167
# White Pixels: 139820
# Black to White Ratio: 1.02
#
# ./Anushka/3xShapes/square_3x.png
# Black Pixels: 138744
# White Pixels: 151548
# Black to White Ratio: 1.09
#
# ./Anushka/3xShapes/ellipse_angle_90_3x.png
# Black Pixels: 189488
# White Pixels: 233563
# Black to White Ratio: 1.23
#
# ./Anushka/3xShapes/rectangle_angle_0_3x.png
# Black Pixels: 208138
# White Pixels: 227855
# Black to White Ratio: 1.09
#
# ./Anushka/3xShapes/ellipse_angle_0_3x.png
# Black Pixels: 215450
# White Pixels: 207831
# Black to White Ratio: 1.04
#
# ./Anushka/3xShapes/trapezium_angle_0_3x.png
# Black Pixels: 138739
# White Pixels: 130205
# Black to White Ratio: 1.07
#
# ./Anushka/3xShapes/parallelogram_angle_0_3x.png
# Black Pixels: 151122
# White Pixels: 118278
# Black to White Ratio: 1.28
#
# ./Anushka/3xShapes/parallelogram_angle_90_3x.png
# Black Pixels: 125920
# White Pixels: 143726
# Black to White Ratio: 1.14
#
# ./Anushka/3xShapes/trapezium_angle_90_3x.png
# Black Pixels: 154142
# White Pixels: 115501
# Black to White Ratio: 1.33
#
# ./Anushka/3xShapes/rectangle_angle_90_3x.png
# Black Pixels: 201841
# White Pixels: 233691
# Black to White Ratio: 1.16
#
# ./Anushka/3xShapes2/circle_3x.png
# Black Pixels: 136069
# White Pixels: 145881
# Black to White Ratio: 1.07
#
# ./Anushka/3xShapes2/square_3x.png
# Black Pixels: 156309
# White Pixels: 134363
# Black to White Ratio: 1.16
#
# ./Anushka/3xShapes2/ellipse_angle_90_3x.png
# Black Pixels: 186958
# White Pixels: 236685
# Black to White Ratio: 1.27
#
# ./Anushka/3xShapes2/rectangle_angle_0_3x.png
# Black Pixels: 217463
# White Pixels: 218568
# Black to White Ratio: 1.01
#
# ./Anushka/3xShapes2/ellipse_angle_0_3x.png
# Black Pixels: 213694
# White Pixels: 209164
# Black to White Ratio: 1.02
#
# ./Anushka/3xShapes2/trapezium_angle_0_3x.png
# Black Pixels: 204448
# White Pixels: 65712
# Black to White Ratio: 3.11
#
# ./Anushka/3xShapes2/parallelogram_angle_0_3x.png
# Black Pixels: 136798
# White Pixels: 133752
# Black to White Ratio: 1.02
#
# ./Anushka/3xShapes2/parallelogram_angle_90_3x.png
# Black Pixels: 136196
# White Pixels: 132681
# Black to White Ratio: 1.03
#
# ./Anushka/3xShapes2/trapezium_angle_90_3x.png
# Black Pixels: 177153
# White Pixels: 91875
# Black to White Ratio: 1.93
#
# ./Anushka/3xShapes2/rectangle_angle_90_3x.png
# Black Pixels: 260528
# White Pixels: 175973
# Black to White Ratio: 1.48
#
# ./Vanshita/3xShapes/circle_3x.png
# Black Pixels: 146412
# White Pixels: 135701
# Black to White Ratio: 1.08
#
# ./Vanshita/3xShapes/square_3x.png
# Black Pixels: 73139
# White Pixels: 216913
# Black to White Ratio: 2.97
#
# ./Vanshita/3xShapes/ellipse_angle_90_3x.png
# Black Pixels: 210931
# White Pixels: 212322
# Black to White Ratio: 1.01
#
# ./Vanshita/3xShapes/rectangle_angle_0_3x.png
# Black Pixels: 136170
# White Pixels: 299970
# Black to White Ratio: 2.20
#
# ./Vanshita/3xShapes/ellipse_angle_0_3x.png
# Black Pixels: 223847
# White Pixels: 199279
# Black to White Ratio: 1.12
#
# ./Vanshita/3xShapes/trapezium_angle_0_3x.png
# Black Pixels: 101245
# White Pixels: 167563
# Black to White Ratio: 1.66
#
# ./Vanshita/3xShapes/parallelogram_angle_0_3x.png
# Black Pixels: 134208
# White Pixels: 134413
# Black to White Ratio: 1.00
#
# ./Vanshita/3xShapes/parallelogram_angle_90_3x.png
# Black Pixels: 134339
# White Pixels: 133690
# Black to White Ratio: 1.00
#
# ./Vanshita/3xShapes/trapezium_angle_90_3x.png
# Black Pixels: 114187
# White Pixels: 154619
# Black to White Ratio: 1.35
#
# ./Vanshita/3xShapes/rectangle_angle_90_3x.png
# Black Pixels: 112696
# White Pixels: 322721
# Black to White Ratio: 2.86
#
# ./Vanshita/3xShapes2/circle_3x.png
# Black Pixels: 217164
# White Pixels: 64700
# Black to White Ratio: 3.36
#
# ./Vanshita/3xShapes2/square_3x.png
# Black Pixels: 143458
# White Pixels: 146112
# Black to White Ratio: 1.02
#
# ./Vanshita/3xShapes2/ellipse_angle_90_3x.png
# Black Pixels: 201168
# White Pixels: 221981
# Black to White Ratio: 1.10
#
# ./Vanshita/3xShapes2/rectangle_angle_0_3x.png
# Black Pixels: 228093
# White Pixels: 207466
# Black to White Ratio: 1.10
#
# ./Vanshita/3xShapes2/ellipse_angle_0_3x.png
# Black Pixels: 212403
# White Pixels: 210684
# Black to White Ratio: 1.01
#
# ./Vanshita/3xShapes2/trapezium_angle_0_3x.png
# Black Pixels: 192476
# White Pixels: 76904
# Black to White Ratio: 2.50
#
# ./Vanshita/3xShapes2/parallelogram_angle_0_3x.png
# Black Pixels: 139216
# White Pixels: 130599
# Black to White Ratio: 1.07
#
# ./Vanshita/3xShapes2/parallelogram_angle_90_3x.png
# Black Pixels: 139742
# White Pixels: 129964
# Black to White Ratio: 1.08
#
# ./Vanshita/3xShapes2/trapezium_angle_90_3x.png
# Black Pixels: 181652
# White Pixels: 87409
# Black to White Ratio: 2.08
#
# ./Vanshita/3xShapes2/rectangle_angle_90_3x.png
# Black Pixels: 225940
# White Pixels: 209978
# Black to White Ratio: 1.08
#
# ./Ashna/1xShapes/trapezium_angle_90.png
# Black Pixels: 14861
# White Pixels: 15383
# Black to White Ratio: 1.04
#
# ./Ashna/1xShapes/parallelogram_angle_90.png
# Black Pixels: 14548
# White Pixels: 15396
# Black to White Ratio: 1.06
#
# ./Ashna/1xShapes/ellipse_angle_90.png
# Black Pixels: 23335
# White Pixels: 23383
# Black to White Ratio: 1.00
#
# ./Ashna/1xShapes/circle.png
# Black Pixels: 16309
# White Pixels: 14869
# Black to White Ratio: 1.10
#
# ./Ashna/1xShapes/rectangle_angle_0.png
# Black Pixels: 24120
# White Pixels: 24177
# Black to White Ratio: 1.00
#
# ./Ashna/1xShapes/rectangle_angle_90.png
# Black Pixels: 24298
# White Pixels: 23849
# Black to White Ratio: 1.02
#
# ./Ashna/1xShapes/trapezium_angle_0.png
# Black Pixels: 14800
# White Pixels: 15350
# Black to White Ratio: 1.04
#
# ./Ashna/1xShapes/ellipse_angle_0.png
# Black Pixels: 25127
# White Pixels: 21795
# Black to White Ratio: 1.15
#
# ./Ashna/1xShapes/parallelogram_angle_0.png
# Black Pixels: 14351
# White Pixels: 15212
# Black to White Ratio: 1.06
#
# ./Ashna/1xShapes/square.png
# Black Pixels: 16019
# White Pixels: 16082
# Black to White Ratio: 1.00
#
# ./Ashna/1xShapes2/trapezium_angle_90.png
# Black Pixels: 16003
# White Pixels: 13761
# Black to White Ratio: 1.16
#
# ./Ashna/1xShapes2/parallelogram_angle_90.png
# Black Pixels: 14837
# White Pixels: 14708
# Black to White Ratio: 1.01
#
# ./Ashna/1xShapes2/ellipse_angle_90.png
# Black Pixels: 23741
# White Pixels: 23189
# Black to White Ratio: 1.02
#
# ./Ashna/1xShapes2/circle.png
# Black Pixels: 15218
# White Pixels: 15981
# Black to White Ratio: 1.05
#
# ./Ashna/1xShapes2/rectangle_angle_0.png
# Black Pixels: 24300
# White Pixels: 23828
# Black to White Ratio: 1.02
#
# ./Ashna/1xShapes2/rectangle_angle_90.png
# Black Pixels: 24660
# White Pixels: 23980
# Black to White Ratio: 1.03
#
# ./Ashna/1xShapes2/trapezium_angle_0.png
# Black Pixels: 16435
# White Pixels: 13546
# Black to White Ratio: 1.21
#
# ./Ashna/1xShapes2/ellipse_angle_0.png
# Black Pixels: 24096
# White Pixels: 22656
# Black to White Ratio: 1.06
#
# ./Ashna/1xShapes2/parallelogram_angle_0.png
# Black Pixels: 15745
# White Pixels: 14214
# Black to White Ratio: 1.11
#
# ./Ashna/1xShapes2/square.png
# Black Pixels: 16200
# White Pixels: 16240
# Black to White Ratio: 1.00
#
# ./Pavani/1xShapes/trapezium_angle_90.png
# Black Pixels: 10066
# White Pixels: 19392
# Black to White Ratio: 1.93
#
# ./Pavani/1xShapes/parallelogram_angle_90.png
# Black Pixels: 14584
# White Pixels: 14767
# Black to White Ratio: 1.01
#
# ./Pavani/1xShapes/ellipse_angle_90.png
# Black Pixels: 23481
# White Pixels: 23240
# Black to White Ratio: 1.01
#
# ./Pavani/1xShapes/circle.png
# Black Pixels: 15907
# White Pixels: 15278
# Black to White Ratio: 1.04
#
# ./Pavani/1xShapes/rectangle_angle_0.png
# Black Pixels: 24126
# White Pixels: 23641
# Black to White Ratio: 1.02
#
# ./Pavani/1xShapes/rectangle_angle_90.png
# Black Pixels: 23626
# White Pixels: 24455
# Black to White Ratio: 1.04
#
# ./Pavani/1xShapes/trapezium_angle_0.png
# Black Pixels: 15265
# White Pixels: 14446
# Black to White Ratio: 1.06
#
# ./Pavani/1xShapes/ellipse_angle_0.png
# Black Pixels: 23628
# White Pixels: 23287
# Black to White Ratio: 1.01
#
# ./Pavani/1xShapes/parallelogram_angle_0.png
# Black Pixels: 14735
# White Pixels: 14808
# Black to White Ratio: 1.00
#
# ./Pavani/1xShapes/square.png
# Black Pixels: 15962
# White Pixels: 15786
# Black to White Ratio: 1.01
#
# ./Pavani/1xShapes2/trapezium_angle_90.png
# Black Pixels: 15107
# White Pixels: 14673
# Black to White Ratio: 1.03
#
# ./Pavani/1xShapes2/parallelogram_angle_90.png
# Black Pixels: 18666
# White Pixels: 10931
# Black to White Ratio: 1.71
#
# ./Pavani/1xShapes2/ellipse_angle_90.png
# Black Pixels: 24781
# White Pixels: 21911
# Black to White Ratio: 1.13
#
# ./Pavani/1xShapes2/circle.png
# Black Pixels: 16299
# White Pixels: 14735
# Black to White Ratio: 1.11
#
# ./Pavani/1xShapes2/rectangle_angle_0.png
# Black Pixels: 24685
# White Pixels: 23250
# Black to White Ratio: 1.06
#
# ./Pavani/1xShapes2/rectangle_angle_90.png
# Black Pixels: 30891
# White Pixels: 17054
# Black to White Ratio: 1.81
#
# ./Pavani/1xShapes2/trapezium_angle_0.png
# Black Pixels: 17724
# White Pixels: 12166
# Black to White Ratio: 1.46
#
# ./Pavani/1xShapes2/ellipse_angle_0.png
# Black Pixels: 24989
# White Pixels: 21759
# Black to White Ratio: 1.15
#
# ./Pavani/1xShapes2/parallelogram_angle_0.png
# Black Pixels: 18181
# White Pixels: 11535
# Black to White Ratio: 1.58
#
# ./Pavani/1xShapes2/square.png
# Black Pixels: 15840
# White Pixels: 16576
# Black to White Ratio: 1.05
#
# ./Rhythm/3xShapes/circle_3x.png
# Black Pixels: 183848
# White Pixels: 98273
# Black to White Ratio: 1.87
#
# ./Rhythm/3xShapes/square_3x.png
# Black Pixels: 135243
# White Pixels: 155404
# Black to White Ratio: 1.15
#
# ./Rhythm/3xShapes/ellipse_angle_90_3x.png
# Black Pixels: 249296
# White Pixels: 173669
# Black to White Ratio: 1.44
#
# ./Rhythm/3xShapes/rectangle_angle_0_3x.png
# Black Pixels: 221064
# White Pixels: 214026
# Black to White Ratio: 1.03
#
# ./Rhythm/3xShapes/ellipse_angle_0_3x.png
# Black Pixels: 277847
# White Pixels: 145437
# Black to White Ratio: 1.91
#
# ./Rhythm/3xShapes/trapezium_angle_0_3x.png
# Black Pixels: 151025
# White Pixels: 118204
# Black to White Ratio: 1.28
#
# ./Rhythm/3xShapes/parallelogram_angle_0_3x.png
# Black Pixels: 152781
# White Pixels: 116153
# Black to White Ratio: 1.32
#
# ./Rhythm/3xShapes/parallelogram_angle_90_3x.png
# Black Pixels: 80703
# White Pixels: 188656
# Black to White Ratio: 2.34
#
# ./Rhythm/3xShapes/trapezium_angle_90_3x.png
# Black Pixels: 188814
# White Pixels: 80781
# Black to White Ratio: 2.34
#
# ./Rhythm/3xShapes/rectangle_angle_90_3x.png
# Black Pixels: 212445
# White Pixels: 222654
# Black to White Ratio: 1.05
#
# ./Rhythm/3xShapes2/circle_3x.png
# Black Pixels: 142994
# White Pixels: 139205
# Black to White Ratio: 1.03
#
# ./Rhythm/3xShapes2/square_3x.png
# Black Pixels: 164126
# White Pixels: 126577
# Black to White Ratio: 1.30
#
# ./Rhythm/3xShapes2/ellipse_angle_90_3x.png
# Black Pixels: 257253
# White Pixels: 166071
# Black to White Ratio: 1.55
#
# ./Rhythm/3xShapes2/rectangle_angle_0_3x.png
# Black Pixels: 254822
# White Pixels: 181267
# Black to White Ratio: 1.41
#
# ./Rhythm/3xShapes2/ellipse_angle_0_3x.png
# Black Pixels: 211931
# White Pixels: 211307
# Black to White Ratio: 1.00
#
# ./Rhythm/3xShapes2/trapezium_angle_0_3x.png
# Black Pixels: 180072
# White Pixels: 89917
# Black to White Ratio: 2.00
#
# ./Rhythm/3xShapes2/parallelogram_angle_0_3x.png
# Black Pixels: 159376
# White Pixels: 110245
# Black to White Ratio: 1.45
#
# ./Rhythm/3xShapes2/parallelogram_angle_90_3x.png
# Black Pixels: 166168
# White Pixels: 102616
# Black to White Ratio: 1.62
#
# ./Rhythm/3xShapes2/trapezium_angle_90_3x.png
# Black Pixels: 188722
# White Pixels: 80564
# Black to White Ratio: 2.34
#
# ./Rhythm/3xShapes2/rectangle_angle_90_3x.png
# Black Pixels: 304569
# White Pixels: 131975
# Black to White Ratio: 2.31
#
# ./Parth/1xShapes/trapezium_angle_90.png
# Black Pixels: 19488
# White Pixels: 10243
# Black to White Ratio: 1.90
#
# ./Parth/1xShapes/parallelogram_angle_90.png
# Black Pixels: 15472
# White Pixels: 14326
# Black to White Ratio: 1.08
#
# ./Parth/1xShapes/ellipse_angle_90.png
# Black Pixels: 23875
# White Pixels: 22804
# Black to White Ratio: 1.05
#
# ./Parth/1xShapes/circle.png
# Black Pixels: 17393
# White Pixels: 13706
# Black to White Ratio: 1.27
#
# ./Parth/1xShapes/rectangle_angle_0.png
# Black Pixels: 24318
# White Pixels: 23745
# Black to White Ratio: 1.02
#
# ./Parth/1xShapes/rectangle_angle_90.png
# Black Pixels: 24837
# White Pixels: 23034
# Black to White Ratio: 1.08
#
# ./Parth/1xShapes/trapezium_angle_0.png
# Black Pixels: 17935
# White Pixels: 11658
# Black to White Ratio: 1.54
#
# ./Parth/1xShapes/ellipse_angle_0.png
# Black Pixels: 23969
# White Pixels: 22728
# Black to White Ratio: 1.05
#
# ./Parth/1xShapes/parallelogram_angle_0.png
# Black Pixels: 16325
# White Pixels: 13315
# Black to White Ratio: 1.23
#
# ./Parth/1xShapes/square.png
# Black Pixels: 16799
# White Pixels: 15165
# Black to White Ratio: 1.11
#
# ./Parth/1xShapes2/trapezium_angle_90.png
# Black Pixels: 16556
# White Pixels: 13165
# Black to White Ratio: 1.26
#
# ./Parth/1xShapes2/parallelogram_angle_90.png
# Black Pixels: 15897
# White Pixels: 13726
# Black to White Ratio: 1.16
#
# ./Parth/1xShapes2/ellipse_angle_90.png
# Black Pixels: 23500
# White Pixels: 23302
# Black to White Ratio: 1.01
#
# ./Parth/1xShapes2/circle.png
# Black Pixels: 16443
# White Pixels: 14663
# Black to White Ratio: 1.12
#
# ./Parth/1xShapes2/rectangle_angle_0.png
# Black Pixels: 24874
# White Pixels: 22983
# Black to White Ratio: 1.08
#
# ./Parth/1xShapes2/rectangle_angle_90.png
# Black Pixels: 24326
# White Pixels: 23621
# Black to White Ratio: 1.03
#
# ./Parth/1xShapes2/trapezium_angle_0.png
# Black Pixels: 13858
# White Pixels: 15921
# Black to White Ratio: 1.15
#
# ./Parth/1xShapes2/ellipse_angle_0.png
# Black Pixels: 25409
# White Pixels: 21243
# Black to White Ratio: 1.20
#
# ./Parth/1xShapes2/parallelogram_angle_0.png
# Black Pixels: 15935
# White Pixels: 13835
# Black to White Ratio: 1.15
#
# ./Parth/1xShapes2/square.png
# Black Pixels: 16761
# White Pixels: 15122
# Black to White Ratio: 1.11
#
# ./Prisha/1xShapes/trapezium_angle_90.png
# Black Pixels: 9764
# White Pixels: 19729
# Black to White Ratio: 2.02
#
# ./Prisha/1xShapes/parallelogram_angle_90.png
# Black Pixels: 14390
# White Pixels: 14968
# Black to White Ratio: 1.04
#
# ./Prisha/1xShapes/ellipse_angle_90.png
# Black Pixels: 24827
# White Pixels: 21887
# Black to White Ratio: 1.13
#
# ./Prisha/1xShapes/circle.png
# Black Pixels: 16745
# White Pixels: 14339
# Black to White Ratio: 1.17
#
# ./Prisha/1xShapes/rectangle_angle_0.png
# Black Pixels: 24760
# White Pixels: 23247
# Black to White Ratio: 1.07
#
# ./Prisha/1xShapes/rectangle_angle_90.png
# Black Pixels: 24402
# White Pixels: 23355
# Black to White Ratio: 1.04
#
# ./Prisha/1xShapes/trapezium_angle_0.png
# Black Pixels: 15202
# White Pixels: 14554
# Black to White Ratio: 1.04
#
# ./Prisha/1xShapes/ellipse_angle_0.png
# Black Pixels: 23467
# White Pixels: 23270
# Black to White Ratio: 1.01
#
# ./Prisha/1xShapes/parallelogram_angle_0.png
# Black Pixels: 15187
# White Pixels: 14177
# Black to White Ratio: 1.07
#
# ./Prisha/1xShapes/square.png
# Black Pixels: 16740
# White Pixels: 15663
# Black to White Ratio: 1.07
#
# ./Prisha/1xShapes2/trapezium_angle_90.png
# Black Pixels: 15601
# White Pixels: 14165
# Black to White Ratio: 1.10
#
# ./Prisha/1xShapes2/parallelogram_angle_90.png
# Black Pixels: 15918
# White Pixels: 13690
# Black to White Ratio: 1.16
#
# ./Prisha/1xShapes2/ellipse_angle_90.png
# Black Pixels: 24141
# White Pixels: 22798
# Black to White Ratio: 1.06
#
# ./Prisha/1xShapes2/circle.png
# Black Pixels: 16215
# White Pixels: 14979
# Black to White Ratio: 1.08
#
# ./Prisha/1xShapes2/rectangle_angle_0.png
# Black Pixels: 25518
# White Pixels: 22580
# Black to White Ratio: 1.13
#
# ./Prisha/1xShapes2/rectangle_angle_90.png
# Black Pixels: 24123
# White Pixels: 24146
# Black to White Ratio: 1.00
#
# ./Prisha/1xShapes2/trapezium_angle_0.png
# Black Pixels: 17122
# White Pixels: 12748
# Black to White Ratio: 1.34
#
# ./Prisha/1xShapes2/ellipse_angle_0.png
# Black Pixels: 23347
# White Pixels: 23403
# Black to White Ratio: 1.00
#
# ./Prisha/1xShapes2/parallelogram_angle_0.png
# Black Pixels: 16122
# White Pixels: 13702
# Black to White Ratio: 1.18
#
# ./Prisha/1xShapes2/square.png
# Black Pixels: 15843
# White Pixels: 16224
# Black to White Ratio: 1.02
#
# ./Mahika/3xShapes/circle_3x.png
# Black Pixels: 153812
# White Pixels: 127818
# Black to White Ratio: 1.20
#
# ./Mahika/3xShapes/square_3x.png
# Black Pixels: 146609
# White Pixels: 142864
# Black to White Ratio: 1.03
#
# ./Mahika/3xShapes/ellipse_angle_90_3x.png
# Black Pixels: 248615
# White Pixels: 174071
# Black to White Ratio: 1.43
#
# ./Mahika/3xShapes/rectangle_angle_0_3x.png
# Black Pixels: 218450
# White Pixels: 216462
# Black to White Ratio: 1.01
#
# ./Mahika/3xShapes/ellipse_angle_0_3x.png
# Black Pixels: 207824
# White Pixels: 215763
# Black to White Ratio: 1.04
#
# ./Mahika/3xShapes/trapezium_angle_0_3x.png
# Black Pixels: 180630
# White Pixels: 87828
# Black to White Ratio: 2.06
#
# ./Mahika/3xShapes/parallelogram_angle_0_3x.png
# Black Pixels: 135551
# White Pixels: 133236
# Black to White Ratio: 1.02
#
# ./Mahika/3xShapes/parallelogram_angle_90_3x.png
# Black Pixels: 133913
# White Pixels: 134672
# Black to White Ratio: 1.01
#
# ./Mahika/3xShapes/trapezium_angle_90_3x.png
# Black Pixels: 157239
# White Pixels: 112239
# Black to White Ratio: 1.40
#
# ./Mahika/3xShapes/rectangle_angle_90_3x.png
# Black Pixels: 210676
# White Pixels: 225134
# Black to White Ratio: 1.07
#
# ./Mahika/3xShapes2/circle_3x.png
# Black Pixels: 143796
# White Pixels: 138387
# Black to White Ratio: 1.04
#
# ./Mahika/3xShapes2/square_3x.png
# Black Pixels: 152028
# White Pixels: 138605
# Black to White Ratio: 1.10
#
# ./Mahika/3xShapes2/ellipse_angle_90_3x.png
# Black Pixels: 212351
# White Pixels: 211250
# Black to White Ratio: 1.01
#
# ./Mahika/3xShapes2/rectangle_angle_0_3x.png
# Black Pixels: 223993
# White Pixels: 211895
# Black to White Ratio: 1.06
#
# ./Mahika/3xShapes2/ellipse_angle_0_3x.png
# Black Pixels: 213704
# White Pixels: 209381
# Black to White Ratio: 1.02
#
# ./Mahika/3xShapes2/trapezium_angle_0_3x.png
# Black Pixels: 115400
# White Pixels: 153260
# Black to White Ratio: 1.33
#
# ./Mahika/3xShapes2/parallelogram_angle_0_3x.png
# Black Pixels: 144461
# White Pixels: 124992
# Black to White Ratio: 1.16
#
# ./Mahika/3xShapes2/parallelogram_angle_90_3x.png
# Black Pixels: 145862
# White Pixels: 122838
# Black to White Ratio: 1.19
#
# ./Mahika/3xShapes2/trapezium_angle_90_3x.png
# Black Pixels: 89581
# White Pixels: 178830
# Black to White Ratio: 2.00
#
# ./Mahika/3xShapes2/rectangle_angle_90_3x.png
# Black Pixels: 230040
# White Pixels: 206282
# Black to White Ratio: 1.12
#
# ./Vrinda/3xShapes/circle_3x.png
# Black Pixels: 133615
# White Pixels: 148532
# Black to White Ratio: 1.11
#
# ./Vrinda/3xShapes/square_3x.png
# Black Pixels: 145077
# White Pixels: 144476
# Black to White Ratio: 1.00
#
# ./Vrinda/3xShapes/ellipse_angle_90_3x.png
# Black Pixels: 206607
# White Pixels: 216967
# Black to White Ratio: 1.05
#
# ./Vrinda/3xShapes/rectangle_angle_0_3x.png
# Black Pixels: 218313
# White Pixels: 216551
# Black to White Ratio: 1.01
#
# ./Vrinda/3xShapes/ellipse_angle_0_3x.png
# Black Pixels: 213963
# White Pixels: 208795
# Black to White Ratio: 1.02
#
# ./Vrinda/3xShapes/trapezium_angle_0_3x.png
# Black Pixels: 135754
# White Pixels: 133505
# Black to White Ratio: 1.02
#
# ./Vrinda/3xShapes/parallelogram_angle_0_3x.png
# Black Pixels: 133916
# White Pixels: 134700
# Black to White Ratio: 1.01
#
# ./Vrinda/3xShapes/parallelogram_angle_90_3x.png
# Black Pixels: 142186
# White Pixels: 127220
# Black to White Ratio: 1.12
#
# ./Vrinda/3xShapes/trapezium_angle_90_3x.png
# Black Pixels: 90331
# White Pixels: 178158
# Black to White Ratio: 1.97
#
# ./Vrinda/3xShapes/rectangle_angle_90_3x.png
# Black Pixels: 225466
# White Pixels: 210332
# Black to White Ratio: 1.07
#
# ./Vrinda/3xShapes2/circle_3x.png
# Black Pixels: 139297
# White Pixels: 142843
# Black to White Ratio: 1.03
#
# ./Vrinda/3xShapes2/square_3x.png
# Black Pixels: 144720
# White Pixels: 146916
# Black to White Ratio: 1.02
#
# ./Vrinda/3xShapes2/ellipse_angle_90_3x.png
# Black Pixels: 178551
# White Pixels: 244588
# Black to White Ratio: 1.37
#
# ./Vrinda/3xShapes2/rectangle_angle_0_3x.png
# Black Pixels: 216294
# White Pixels: 219662
# Black to White Ratio: 1.02
#
# ./Vrinda/3xShapes2/ellipse_angle_0_3x.png
# Black Pixels: 214118
# White Pixels: 210608
# Black to White Ratio: 1.02
#
# ./Vrinda/3xShapes2/trapezium_angle_0_3x.png
# Black Pixels: 179280
# White Pixels: 89197
# Black to White Ratio: 2.01
#
# ./Vrinda/3xShapes2/parallelogram_angle_0_3x.png
# Black Pixels: 141308
# White Pixels: 128357
# Black to White Ratio: 1.10
#
# ./Vrinda/3xShapes2/parallelogram_angle_90_3x.png
# Black Pixels: 136812
# White Pixels: 132097
# Black to White Ratio: 1.04
#
# ./Vrinda/3xShapes2/trapezium_angle_90_3x.png
# Black Pixels: 131416
# White Pixels: 137905
# Black to White Ratio: 1.05
#
# ./Vrinda/3xShapes2/rectangle_angle_90_3x.png
# Black Pixels: 228145
# White Pixels: 208364
# Black to White Ratio: 1.09
#
# ./Bhargav/1xShapes/trapezium_angle_90.png
# Black Pixels: 21974
# White Pixels: 8217
# Black to White Ratio: 2.67
#
# ./Bhargav/1xShapes/parallelogram_angle_90.png
# Black Pixels: 25242
# White Pixels: 4546
# Black to White Ratio: 5.55
#
# ./Bhargav/1xShapes/ellipse_angle_90.png
# Black Pixels: 22064
# White Pixels: 24605
# Black to White Ratio: 1.12
#
# ./Bhargav/1xShapes/circle.png
# Black Pixels: 3638
# White Pixels: 27548
# Black to White Ratio: 7.57
#
# ./Bhargav/1xShapes/rectangle_angle_0.png
# Black Pixels: 23220
# White Pixels: 25412
# Black to White Ratio: 1.09
#
# ./Bhargav/1xShapes/rectangle_angle_90.png
# Black Pixels: 23460
# White Pixels: 24324
# Black to White Ratio: 1.04
#
# ./Bhargav/1xShapes/trapezium_angle_0.png
# Black Pixels: 5150
# White Pixels: 24653
# Black to White Ratio: 4.79
#
# ./Bhargav/1xShapes/ellipse_angle_0.png
# Black Pixels: 23925
# White Pixels: 23356
# Black to White Ratio: 1.02
#
# ./Bhargav/1xShapes/parallelogram_angle_0.png
# Black Pixels: 15234
# White Pixels: 14313
# Black to White Ratio: 1.06
#
# ./Bhargav/1xShapes/square.png
# Black Pixels: 15120
# White Pixels: 17318
# Black to White Ratio: 1.15
#
# ./Bhargav/1xShapes2/trapezium_angle_90.png
# Black Pixels: 19553
# White Pixels: 10134
# Black to White Ratio: 1.93
#
# ./Bhargav/1xShapes2/parallelogram_angle_90.png
# Black Pixels: 15025
# White Pixels: 14459
# Black to White Ratio: 1.04
#
# ./Bhargav/1xShapes2/ellipse_angle_90.png
# Black Pixels: 41633
# White Pixels: 5420
# Black to White Ratio: 7.68
#
# ./Bhargav/1xShapes2/circle.png
# Black Pixels: 3528
# White Pixels: 27662
# Black to White Ratio: 7.84
#
# ./Bhargav/1xShapes2/rectangle_angle_0.png
# Black Pixels: 26730
# White Pixels: 21914
# Black to White Ratio: 1.22
#
# ./Bhargav/1xShapes2/rectangle_angle_90.png
# Black Pixels: 25740
# White Pixels: 22894
# Black to White Ratio: 1.12
#
# ./Bhargav/1xShapes2/trapezium_angle_0.png
# Black Pixels: 8874
# White Pixels: 21346
# Black to White Ratio: 2.41
#
# ./Bhargav/1xShapes2/ellipse_angle_0.png
# Black Pixels: 24435
# White Pixels: 22241
# Black to White Ratio: 1.10
#
# ./Bhargav/1xShapes2/parallelogram_angle_0.png
# Black Pixels: 13502
# White Pixels: 16658
# Black to White Ratio: 1.23
#
# ./Bhargav/1xShapes2/square.png
# Black Pixels: 16200
# White Pixels: 16236
# Black to White Ratio: 1.00
#
# ./Khushi/3xShapes/circle_3x.png
# Black Pixels: 143182
# White Pixels: 138891
# Black to White Ratio: 1.03
#
# ./Khushi/3xShapes/square_3x.png
# Black Pixels: 156870
# White Pixels: 133832
# Black to White Ratio: 1.17
#
# ./Khushi/3xShapes/ellipse_angle_90_3x.png
# Black Pixels: 212705
# White Pixels: 211061
# Black to White Ratio: 1.01
#
# ./Khushi/3xShapes/rectangle_angle_0_3x.png
# Black Pixels: 221671
# White Pixels: 214834
# Black to White Ratio: 1.03
#
# ./Khushi/3xShapes/ellipse_angle_0_3x.png
# Black Pixels: 212282
# White Pixels: 211538
# Black to White Ratio: 1.00
#
# ./Khushi/3xShapes/trapezium_angle_0_3x.png
# Black Pixels: 219906
# White Pixels: 49343
# Black to White Ratio: 4.46
#
# ./Khushi/3xShapes/parallelogram_angle_0_3x.png
# Black Pixels: 134659
# White Pixels: 133949
# Black to White Ratio: 1.01
#
# ./Khushi/3xShapes/parallelogram_angle_90_3x.png
# Black Pixels: 132854
# White Pixels: 135193
# Black to White Ratio: 1.02
#
# ./Khushi/3xShapes/trapezium_angle_90_3x.png
# Black Pixels: 181487
# White Pixels: 88147
# Black to White Ratio: 2.06
#
# ./Khushi/3xShapes/rectangle_angle_90_3x.png
# Black Pixels: 224223
# White Pixels: 211825
# Black to White Ratio: 1.06
#
# ./Khushi/3xShapes2/circle_3x.png
# Black Pixels: 142348
# White Pixels: 140162
# Black to White Ratio: 1.02
#
# ./Khushi/3xShapes2/square_3x.png
# Black Pixels: 154456
# White Pixels: 136289
# Black to White Ratio: 1.13
#
# ./Khushi/3xShapes2/ellipse_angle_90_3x.png
# Black Pixels: 220053
# White Pixels: 203604
# Black to White Ratio: 1.08
#
# ./Khushi/3xShapes2/rectangle_angle_0_3x.png
# Black Pixels: 237755
# White Pixels: 198378
# Black to White Ratio: 1.20
#
# ./Khushi/3xShapes2/ellipse_angle_0_3x.png
# Black Pixels: 211856
# White Pixels: 212025
# Black to White Ratio: 1.00
#
# ./Khushi/3xShapes2/trapezium_angle_0_3x.png
# Black Pixels: 169245
# White Pixels: 100773
# Black to White Ratio: 1.68
#
# ./Khushi/3xShapes2/parallelogram_angle_0_3x.png
# Black Pixels: 150280
# White Pixels: 119523
# Black to White Ratio: 1.26
#
# ./Khushi/3xShapes2/parallelogram_angle_90_3x.png
# Black Pixels: 127462
# White Pixels: 141321
# Black to White Ratio: 1.11
#
# ./Khushi/3xShapes2/trapezium_angle_90_3x.png
# Black Pixels: 226200
# White Pixels: 43171
# Black to White Ratio: 5.24
#
# ./Khushi/3xShapes2/rectangle_angle_90_3x.png
# Black Pixels: 245441
# White Pixels: 191075
# Black to White Ratio: 1.28

# %%
import pandas as pd
df=pd.DataFrame(final)
df.to_csv('Experiment2Data.csv', index=False)
